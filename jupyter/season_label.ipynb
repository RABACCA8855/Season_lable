# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/data/stef/guanguo/A_B_test/1year.csv')
# Out:
# /env-ssd/ljj/miniconda3/envs/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data
# Out:
#          Unnamed: 0               Search Term  \
# 0                 0            iphone 11 case
# 1                 1                    pop it
# 2                 2    iphone 12 pro max case
# 3                 3                   dresses
# 4                 4          apple watch band
# ...             ...                       ...
# 5876013     5876013                    ph150b
# 5876014     5876014  sweet magical edible ink
# 5876015     5876015      patiofurniturecovers
# 5876016     5876016        popping gel polish
# 5876017     5876017   shelf replacement board
#
#                                                    count_x  \
# 0        1%07 2%07 1%07 1%07 1%07 1%07 1%07 1%07 1%07 9...
# 1        2%07 4%07 2%07 2%07 2%07 2%07 2%07 2%07 2%07 1...
# 2        3%07 5%07 4%07 6%07 3%07 4%07 4%07 3%07 3%07 7...
# 3        4%07 7%07 10%07 12%07 11%07 5%07 9%07 10%07 12...
# 4        5%07 6%07 5%07 7%07 4%07 3%07 6%07 7%07 9%07 6...
# ...

# %%
df = data[['Search Term','count']]

# %%
df.head()
# Out:
#               Search Term                                              count
# 0          iphone 11 case  1%07 2%07 1%07 1%07 1%07 1%07 1%07 1%07 1%07 9...
# 1                  pop it  2%07 4%07 2%07 2%07 2%07 2%07 2%07 2%07 2%07 1...
# 2  iphone 12 pro max case  3%07 5%07 4%07 6%07 3%07 4%07 4%07 3%07 3%07 7...
# 3                 dresses  4%07 7%07 10%07 12%07 11%07 5%07 9%07 10%07 12...
# 4        apple watch band  5%07 6%07 5%07 7%07 4%07 3%07 6%07 7%07 9%07 6...

# %%
data_01 = np.array(df.head()).tolist()
for item in data_01:
    print(item)
# Out:
# ['iphone 11 case', '1%07 2%07 1%07 1%07 1%07 1%07 1%07 1%07 1%07 9%07 5%07 5%07 5%08 10%08 10%08 9%08 10%08 12%08 12%08 14%08 14%08 16%08 16%08 13%08 12%08 11%08 16%08 14%08 12%08 13%08 13%08 11%08 10%08 12%08 85%08 16%08 17%08 14%08 15%08 12%08 14%08 13%08 14%08 14%09 14%09 12%09 12%09 11%09 12%09 13%09 17%09 17%09 14%09 15%09 13%09 15%09 9%09 10%09 11%09 13%09 11%09 13%09 14%09 12%09 10%09 14%09 11%09 10%09 13%09 12%09 13%09 13%09 17%09 18%10 15%10 15%10 12%10 15%10 19%10 20%10 23%10 191%10 16%10 21%10 19%10 24%10 26%10 26%10 25%10 26%10 28%10 23%10 23%10 26%10 27%10 31%10 33%10 36%10 33%10 24%10 17%10 22%10 23%10 128%11 21%11 18%11 23%11 21%11 29%11 29%11 29%11 25%11 26%11 32%11 29%11 34%11 39%11 38%11 32%11 33%11 40%11 36%11 41%11 41%11 44%11 46%11 45%11 57%11 75%11 3%01 3%01 4%01 5%01 5%01 5%01 5%01 8%01 6%01 6%01 7%01 6%01 7%01 8%01 3%01 4%01 5%01 8%01 10%01 8%01 10%01 12%01 10%01 8%01 7%01 9%01 9%01 8%01 7%01 6%01 7%01 12%02 12%02 13%02 12%02 15%02 13%02 11%02 9%02 11%02 12%02
# ...

# %%
df.head().to_csv('small_case.csv')
